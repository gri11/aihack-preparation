# %% [markdown]
# <a href="https://colab.research.google.com/github/gri11/aihack-preparation/blob/main/aihack_preparation_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Change in Github

# %% [markdown]
# # Set Up Environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Import Datasets

# %%
# download google drive folder from https://drive.google.com/drive/folders/1zRNQQTINKhlT33L0YLJYqcwKzKujbykT?usp=sharing
# !gdown 1zRNQQTINKhlT33L0YLJYqcwKzKujbykT --folder -O pre_practice_task_2023
# Out:
# Retrieving folder list
# Processing file 1Gvuewn46fPgazzrxVLmaueRvUet5o2us 2023 Pre Practice (Task).zip
# Processing file 1XpreA4bQLg2bBgdvqk7ClNDC6xtTvKyK 2023 Pre-Practice Task Explanation.pptx
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1Gvuewn46fPgazzrxVLmaueRvUet5o2us
# To: /content/pre_practice_task_2023/2023 Pre Practice (Task).zip
# 100% 1.81M/1.81M [00:00<00:00, 166MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1XpreA4bQLg2bBgdvqk7ClNDC6xtTvKyK
# To: /content/pre_practice_task_2023/2023 Pre-Practice Task Explanation.pptx
# 100% 1.27M/1.27M [00:00<00:00, 116MB/s]
# Download completed

# %%
# unzip data
# !unzip 'pre_practice_task_2023/2023 Pre Practice (Task).zip' -d pre_practice_task_2023
# Out:
# Archive:  pre_practice_task_2023/2023 Pre Practice (Task).zip
# replace pre_practice_task_2023/__MACOSX/._2023 Pre Practice (Task)? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %% [markdown]
# # Data

# %% [markdown]
# ## Data Exploration

# %%
df = pd.read_csv(
    "pre_practice_task_2023/2023 Pre Practice (Task)/Titanic_sample/train.csv"
)

test_df = pd.read_csv(
    "pre_practice_task_2023/2023 Pre Practice (Task)/Titanic_sample/test.csv"
)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 717          718         1       2
# 718          719         0       3
# 719          720         0       3
# 720          721         1       2
# 721          722         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 717                Troutt, Miss. Edwina Celia "Winnie"  female  27.0      0
# 718                                McEvoy, Mr. Michael    male   NaN      0
# 719                       Johnson, Mr. Malkolm Joackim    male  33.0      0
# 720                  Harper, Miss. Annie Jessie "Nina"  female   6.0      0
# 721                          Jensen, Mr. Svend Lauritz    male  17.0      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 717      0             34218  10.5000  E101        S
# 718      0             36568  15.5000   NaN        Q
# 719      0            347062   7.7750   NaN        S
# 720      1            248727  33.0000   NaN        S
# 721      0            350048   7.0542   NaN        S
#
# [722 rows x 12 columns]

# %%
test_df
# Out:
#      PassengerId  Pclass                                         Name     Sex  \
# 0            723       2                 Gillespie, Mr. William Henry    male
# 1            724       2                      Hodges, Mr. Henry Price    male
# 2            725       1                Chambers, Mr. Norman Campbell    male
# 3            726       3                          Oreskovic, Mr. Luka    male
# 4            727       2  Renouf, Mrs. Peter Henry (Lillian Jefferys)  female
# ..           ...     ...                                          ...     ...
# 164          887       2                        Montvila, Rev. Juozas    male
# 165          888       1                 Graham, Miss. Margaret Edith  female
# 166          889       3     Johnston, Miss. Catherine Helen "Carrie"  female
# 167          890       1                        Behr, Mr. Karl Howell    male
# 168          891       3                          Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0    34.0      0      0       12233  13.0000   NaN        S
# 1    50.0      0      0      250643  13.0000   NaN        S
# 2    27.0      1      0      113806  53.1000    E8        S
# 3    20.0      0      0      315094   8.6625   NaN        S
# 4    30.0      3      0       31027  21.0000   NaN        S
# ..    ...    ...    ...         ...      ...   ...      ...
# 164  27.0      0      0      211536  13.0000   NaN        S
# 165  19.0      0      0      112053  30.0000   B42        S
# 166   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 167  26.0      0      0      111369  30.0000  C148        C
# 168  32.0      0      0      370376   7.7500   NaN        Q
#
# [169 rows x 11 columns]

# %% [markdown]
# ## Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722 entries, 0 to 721
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  722 non-null    int64
#  1   Survived     722 non-null    int64
#  2   Pclass       722 non-null    int64
#  3   Name         722 non-null    object
#  4   Sex          722 non-null    object
#  5   Age          574 non-null    float64
#  6   SibSp        722 non-null    int64
#  7   Parch        722 non-null    int64
#  8   Ticket       722 non-null    object
#  9   Fare         722 non-null    float64
#  10  Cabin        166 non-null    object
#  11  Embarked     721 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 67.8+ KB

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# ..           ...       ...     ...
# 692          693         1       3
# 697          698         1       3
# 709          710         1       3
# 711          712         0       1
# 718          719         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 5                                     Moran, Mr. James    male  NaN      0
# 17                        Williams, Mr. Charles Eugene    male  NaN      0
# 19                             Masselmani, Mrs. Fatima  female  NaN      0
# 26                             Emir, Mr. Farred Chehab    male  NaN      0
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0
# ..                                                 ...     ...  ...    ...
# 692                                       Lam, Mr. Ali    male  NaN      0
# 697                   Mullens, Miss. Katherine "Katie"  female  NaN      0
# 709  Moubarek, Master. Halim Gonios ("William George")    male  NaN      1
# 711                                 Klaber, Mr. Herman    male  NaN      0
# 718                                McEvoy, Mr. Michael    male  NaN      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 5        0  330877   8.4583   NaN        Q
# 17       0  244373  13.0000   NaN        S
# 19       0    2649   7.2250   NaN        C
# 26       0    2631   7.2250   NaN        C
# 28       0  330959   7.8792   NaN        Q
# ..     ...     ...      ...   ...      ...
# 692      0    1601  56.4958   NaN        S
# 697      0   35852   7.7333   NaN        Q
# 709      1    2661  15.2458   NaN        C
# 711      0  113028  26.5500  C124        S
# 718      0   36568  15.5000   NaN        Q
#
# [148 rows x 12 columns]

# %% [markdown]
# # AutoML

# %% [markdown]
# ## Autogluon

# %% [markdown]
# ## Pycaret

# %%
# !pip install -Uq pycaret

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from pycaret.classification import *

s = setup(df, target="Survived", session_id=123)
# Out:
# <style type="text/css">
# #T_66a7c_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_66a7c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66a7c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_66a7c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66a7c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66a7c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_66a7c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66a7c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_66a7c_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_66a7c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_66a7c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_66a7c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_66a7c_row3_col1" class="data row3 col1" >(722, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_66a7c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_66a7c_row4_col1" class="data row4 col1" >(722, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_66a7c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_66a7c_row5_col1" class="data row5 col1" >(505, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_66a7c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_66a7c_row6_col1" class="data row6 col1" >(217, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_66a7c_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_66a7c_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_66a7c_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_66a7c_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_66a7c_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_66a7c_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_66a7c_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_66a7c_row10_col1" class="data row10 col1" >79.1%</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_66a7c_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_66a7c_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_66a7c_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_66a7c_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_66a7c_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_66a7c_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_66a7c_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_66a7c_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_66a7c_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_66a7c_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_66a7c_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_66a7c_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_66a7c_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_66a7c_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_66a7c_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_66a7c_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_66a7c_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_66a7c_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_66a7c_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_66a7c_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_66a7c_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_66a7c_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_66a7c_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_66a7c_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_66a7c_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_66a7c_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_66a7c_row23_col1" class="data row23 col1" >2448</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_config('X_train')
# Out:
#      PassengerId  Pclass                                               Name  \
# 614          615       3                    Brocklebank, Mr. William Alfred
# 543          544       2                                  Beane, Mr. Edward
# 480          481       3                     Goodwin, Master. Harold Victor
# 192          193       3    Andersen-Jensen, Miss. Carla Christine Nielsine
# 447          448       1                        Seward, Mr. Frederic Kimber
# ..           ...     ...                                                ...
# 431          432       3  Thorneycroft, Mrs. Percival (Florence Kate White)
# 314          315       2                                 Hart, Mr. Benjamin
# 338          339       3                              Dahl, Mr. Karl Edwart
# 683          684       3                        Goodwin, Mr. Charles Edward
# 342          343       2                         Collander, Mr. Erik Gustaf
#
#         Sex   Age  SibSp  Parch        Ticket       Fare Cabin Embarked
# 614    male  35.0      0      0        364512   8.050000   NaN        S
# 543    male  32.0      1      0          2908  26.000000   NaN        S
# 480    male   9.0      5      2       CA 2144  46.900002   NaN        S
# 192  female  19.0      1      0        350046   7.854200   NaN        S
# 447    male  34.0      0      0        113794  26.549999   NaN        S
# ..      ...   ...    ...    ...           ...        ...   ...      ...
# 431  female   NaN      1      0        376564  16.100000   NaN        S
# 314    male  43.0      1      1  F.C.C. 13529  26.250000   NaN        S
# 338    male  45.0      0      0          7598   8.050000   NaN        S
# 683    male  14.0      5      2       CA 2144  46.900002   NaN        S
# 342    male  28.0      0      0        248740  13.000000   NaN        S
#
# [505 rows x 11 columns]

# %%
get_config('X_train_transformed')
# Out:
#      PassengerId  Pclass      Name  Sex        Age  SibSp  Parch    Ticket  \
# 614        615.0     3.0  0.339344  1.0  35.000000    0.0    0.0  0.339344
# 543        544.0     2.0  0.469452  1.0  32.000000    1.0    0.0  0.476614
# 480        481.0     3.0  0.339344  1.0   9.000000    5.0    2.0  0.324570
# 192        193.0     3.0  0.469452  0.0  19.000000    1.0    0.0  0.469452
# 447        448.0     1.0  0.469452  1.0  34.000000    0.0    0.0  0.469452
# ..           ...     ...       ...  ...        ...    ...    ...       ...
# 431        432.0     3.0  0.469452  0.0  29.944724    1.0    0.0  0.405689
# 314        315.0     2.0  0.339344  1.0  43.000000    1.0    1.0  0.339344
# 338        339.0     3.0  0.469452  1.0  45.000000    0.0    0.0  0.469452
# 683        684.0     3.0  0.339344  1.0  14.000000    5.0    2.0  0.324570
# 342        343.0     2.0  0.339344  1.0  28.000000    0.0    0.0  0.339344
#
#           Fare     Cabin  Embarked_S  Embarked_Q  Embarked_C
# 614   8.050000  0.312655         1.0         0.0         0.0
# 543  26.000000  0.312655         1.0         0.0         0.0
# 480  46.900002  0.312655         1.0         0.0         0.0
# 192   7.854200  0.312655         1.0         0.0         0.0
# 447  26.549999  0.312655         1.0         0.0         0.0
# ..         ...       ...         ...         ...         ...
# 431  16.100000  0.312655         1.0         0.0         0.0
# 314  26.250000  0.312655         1.0         0.0         0.0
# 338   8.050000  0.312655         1.0         0.0         0.0
# 683  46.900002  0.312655         1.0         0.0         0.0
# 342  13.000000  0.312655         1.0         0.0         0.0
#
# [505 rows x 13 columns]

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_56a19 th {
#   text-align: left;
# }
# #T_56a19_row0_col0, #T_56a19_row0_col4, #T_56a19_row1_col0, #T_56a19_row1_col1, #T_56a19_row1_col2, #T_56a19_row1_col3, #T_56a19_row1_col5, #T_56a19_row1_col6, #T_56a19_row1_col7, #T_56a19_row2_col0, #T_56a19_row2_col1, #T_56a19_row2_col2, #T_56a19_row2_col3, #T_56a19_row2_col4, #T_56a19_row2_col5, #T_56a19_row2_col6, #T_56a19_row2_col7, #T_56a19_row3_col0, #T_56a19_row3_col1, #T_56a19_row3_col2, #T_56a19_row3_col3, #T_56a19_row3_col4, #T_56a19_row3_col5, #T_56a19_row3_col6, #T_56a19_row3_col7, #T_56a19_row4_col0, #T_56a19_row4_col1, #T_56a19_row4_col2, #T_56a19_row4_col3, #T_56a19_row4_col4, #T_56a19_row4_col5, #T_56a19_row4_col6, #T_56a19_row4_col7, #T_56a19_row5_col0, #T_56a19_row5_col1, #T_56a19_row5_col2, #T_56a19_row5_col3, #T_56a19_row5_col4, #T_56a19_row5_col5, #T_56a19_row5_col6, #T_56a19_row5_col7, #T_56a19_row6_col0, #T_56a19_row6_col1, #T_56a19_row6_col2, #T_56a19_row6_col3, #T_56a19_row6_col4, #T_56a19_row6_col5, #T_56a19_row6_col6, #T_56a19_row6_col7, #T_56a19_row7_col0, #T_56a19_row7_col1, #T_56a19_row7_col2, #T_56a19_row7_col3, #T_56a19_row7_col4, #T_56a19_row7_col5, #T_56a19_row7_col6, #T_56a19_row7_col7, #T_56a19_row8_col0, #T_56a19_row8_col1, #T_56a19_row8_col2, #T_56a19_row8_col3, #T_56a19_row8_col4, #T_56a19_row8_col5, #T_56a19_row8_col6, #T_56a19_row8_col7, #T_56a19_row9_col0, #T_56a19_row9_col1, #T_56a19_row9_col2, #T_56a19_row9_col3, #T_56a19_row9_col4, #T_56a19_row9_col5, #T_56a19_row9_col6, #T_56a19_row9_col7, #T_56a19_row10_col0, #T_56a19_row10_col1, #T_56a19_row10_col2, #T_56a19_row10_col3, #T_56a19_row10_col4, #T_56a19_row10_col5, #T_56a19_row10_col6, #T_56a19_row10_col7, #T_56a19_row11_col0, #T_56a19_row11_col1, #T_56a19_row11_col2, #T_56a19_row11_col3, #T_56a19_row11_col4, #T_56a19_row11_col5, #T_56a19_row11_col6, #T_56a19_row11_col7, #T_56a19_row12_col0, #T_56a19_row12_col1, #T_56a19_row12_col2, #T_56a19_row12_col3, #T_56a19_row12_col4, #T_56a19_row12_col5, #T_56a19_row12_col6, #T_56a19_row12_col7, #T_56a19_row13_col0, #T_56a19_row13_col1, #T_56a19_row13_col2, #T_56a19_row13_col3, #T_56a19_row13_col4, #T_56a19_row13_col5, #T_56a19_row13_col6, #T_56a19_row13_col7, #T_56a19_row14_col0, #T_56a19_row14_col1, #T_56a19_row14_col2, #T_56a19_row14_col3, #T_56a19_row14_col4, #T_56a19_row14_col5, #T_56a19_row14_col6, #T_56a19_row14_col7 {
#   text-align: left;
# }
# #T_56a19_row0_col1, #T_56a19_row0_col2, #T_56a19_row0_col3, #T_56a19_row0_col5, #T_56a19_row0_col6, #T_56a19_row0_col7, #T_56a19_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_56a19_row0_col8, #T_56a19_row1_col8, #T_56a19_row2_col8, #T_56a19_row3_col8, #T_56a19_row4_col8, #T_56a19_row5_col8, #T_56a19_row6_col8, #T_56a19_row7_col8, #T_56a19_row8_col8, #T_56a19_row9_col8, #T_56a19_row11_col8, #T_56a19_row12_col8, #T_56a19_row13_col8, #T_56a19_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_56a19_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_56a19" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56a19_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_56a19_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_56a19_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_56a19_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_56a19_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_56a19_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_56a19_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_56a19_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_56a19_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56a19_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_56a19_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_56a19_row0_col1" class="data row0 col1" >0.7960</td>
#       <td id="T_56a19_row0_col2" class="data row0 col2" >0.8561</td>
#       <td id="T_56a19_row0_col3" class="data row0 col3" >0.6750</td>
#       <td id="T_56a19_row0_col4" class="data row0 col4" >0.7845</td>
#       <td id="T_56a19_row0_col5" class="data row0 col5" >0.7189</td>
#       <td id="T_56a19_row0_col6" class="data row0 col6" >0.5612</td>
#       <td id="T_56a19_row0_col7" class="data row0 col7" >0.5709</td>
#       <td id="T_56a19_row0_col8" class="data row0 col8" >1.5130</td>
#     </tr>
#     <tr>
#       <th id="T_56a19_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_56a19_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_56a19_row1_col1" class="data row1 col1" >0.7545</td>
#       <td id="T_56a19_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_56a19_row1_col3" class="data row1 col3" >0.4624</td>
#       <td id="T_56a19_row1_col4" class="data row1 col4" >0.8526</td>
#       <td id="T_56a19_row1_col5" class="data row1 col5" >0.5894</td>
#       <td id="T_56a19_row1_col6" class="data row1 col6" >0.4379</td>
#       <td id="T_56a19_row1_col7" class="data row1 col7" >0.4845</td>
#       <td id="T_56a19_row1_col8" class="data row1 col8" >0.5120</td>
#     </tr>
#     <tr>
#       <th id="T_56a19_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_56a19_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_56a19_row2_col1" class="data row2 col1" >0.7445</td>
#       <td id="T_56a19_row2_col2" class="data row2 col2" >0.8146</td>
#       <td id="T_56a19_row2_col3" class="data row2 col3" >0.4595</td>
#       <td id="T_56a19_row2_col4" class="data row2 col4" >0.8154</td>
#       <td id="T_56a19_row2_col5" class="data row2 col5" >0.5651</td>
#       <td id="T_56a19_row2_col6" class="data row2 col6" >0.4120</td>
#       <td id="T_56a19_row2_col7" class="data row2 col7" >0.4552</td>
#       <td id="T_56a19_row2_col8" class="data row2 col8" >0.3690</td>
#     </tr>
#     <tr>
#       <th id="T_56a19_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_56a19_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_56a19_row3_col1" class="data row3 col1" >0.6258</td>
#       <td id="T_56a19_row3_col2" class="data row3 col2" >0.8060</td>
#       <td id="T_56a19_row3_col3" class="data row3 col3" >0.0716</td>
#       <td id="T_56a19_row3_col4" class="data row3 col4" >0.6071</td>
#       <td id="T_56a19_row3_col5" class="data row3 col5" >0.1223</td>
#       <td id="T_56a19_row3_col6" class="data row3 col6" >0.0615</td>
#       <td id="T_56a19_row3_col7" class="data row3 col7" >0.1219</td>
#       <td id="T_56a19_row3_col8" class="data row3 col8" >0.2490</td>
#     </tr>
#     <tr>
#       <th id="T_56a19_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_56a19_row4_col0" class="data row4 col0" >Decision Tree Classifier</td>
#       <td id="T_56a19_row4_col1" class="data row4 col1" >0.6099</td>
#       <td id="T_56a19_row4_col2" class="data row4 col2" >0.5000</td>
#       <td id="T_56a19_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_56a19_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_56a19_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_56a19_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_56a19_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_56a19_row4_col8" class="data row4 col8" >0.2800</td>
#     </tr>
#     <tr>
#       <th id="T_56a19_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_56a19_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_56a19_row5_col1" class="data row5 col1" >0.6099</td>
#       <td id="T_56a19_row5_col2" class="data row5 col2" >0.5000</td>
#       <td id="T_56a19_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_56a19_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_56a19_row5_col5" class="da
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
print(best)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_afe9c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afe9c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_afe9c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_afe9c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_afe9c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_afe9c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_afe9c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_afe9c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_afe9c_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afe9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_afe9c_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_afe9c_row0_col1" class="data row0 col1" >0.8203</td>
#       <td id="T_afe9c_row0_col2" class="data row0 col2" >0.8641</td>
#       <td id="T_afe9c_row0_col3" class="data row0 col3" >0.6824</td>
#       <td id="T_afe9c_row0_col4" class="data row0 col4" >0.8286</td>
#       <td id="T_afe9c_row0_col5" class="data row0 col5" >0.7484</td>
#       <td id="T_afe9c_row0_col6" class="data row0 col6" >0.6106</td>
#       <td id="T_afe9c_row0_col7" class="data row0 col7" >0.6176</td>
#     </tr>
#   </tbody>
# </table>
#      PassengerId  Pclass                                  Name     Sex    Age  \
# 500          501       3                      Calic, Mr. Petar    male  17.00
# 135          136       2                    Richard, Mr. Emile    male  23.00
# 535          536       2                Hart, Miss. Eva Miriam  female   7.00
# 305          306       1        Allison, Master. Hudson Trevor    male   0.92
# 131          132       3        Coelho, Mr. Domingos Fernandeo    male  20.00
# ..           ...     ...                                   ...     ...    ...
# 682          683       3           Olsvigen, Mr. Thor Anderson    male  20.00
# 205          206       3            Strom, Miss. Telma Matilda  female   2.00
# 630          631       1  Barkworth, Mr. Algernon Henry Wilson    male  80.00
# 78            79       2         Caldwell, Master. Alden Gates    male   0.83
# 629          630       3              O'Connell, Mr. Patrick D    male    NaN
#
#      SibSp  Parch              Ticket        Fare    Cabin Embarked  Survived  \
# 500      0      0              315086    8.662500      NaN        S         0
# 135      0      0       SC/PARIS 2133   15.045800      NaN        C         0
# 535      0      2        F.C.C. 13529   26.250000      NaN        S         1
# 305      1      2              113781  151.550003  C22 C26        S         1
# 131      0      0  SOTON/O.Q. 3101307    7.050000      NaN        S         0
# ..     ...    ...                 ...         ...      ...      ...       ...
# 682      0      0                6563    9.225000      NaN        S         0
# 205      0      1              347054   10.462500       G6        S         0
# 630      0      0               27042   30.000000      A23        S         1
# 78       0      2              248738   29.000000      NaN        S         1
# 629      0      0              334912    7.733300      NaN        Q         0
#
#      prediction_label  prediction_score
# 500                 0            0.8205
# 135                 0            0.6540
# 535                 1            0.7247
# 305                 0            0.5123
# 131                 0            0.8477
# ..                ...               ...
# 682                 0            0.8206
# 205                 1            0.6046
# 630                 0            0.7609
# 78                  0            0.5730
# 629                 0            0.7931
#
# [217 rows x 14 columns]

# %%
predict_model(best)

# %%
predictions = predict_model(best, data=df)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_b0483" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0483_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b0483_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_b0483_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_b0483_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_b0483_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_b0483_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_b0483_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_b0483_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0483_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b0483_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_b0483_row0_col1" class="data row0 col1" >0.8920</td>
#       <td id="T_b0483_row0_col2" class="data row0 col2" >0.9518</td>
#       <td id="T_b0483_row0_col3" class="data row0 col3" >0.7979</td>
#       <td id="T_b0483_row0_col4" class="data row0 col4" >0.9146</td>
#       <td id="T_b0483_row0_col5" class="data row0 col5" >0.8523</td>
#       <td id="T_b0483_row0_col6" class="data row0 col6" >0.7677</td>
#       <td id="T_b0483_row0_col7" class="data row0 col7" >0.7722</td>
#     </tr>
#   </tbody>
# </table>
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket       Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.250000   NaN        S
# 1  female  38.0      1      0          PC 17599  71.283302   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.925000   NaN        S
# 3  female  35.0      1      0            113803  53.099998  C123        S
# 4    male  35.0      0      0            373450   8.050000   NaN        S
#
#    Survived  prediction_label  prediction_score
# 0         0                 0            0.9285
# 1         1                 1            0.8413
# 2         1                 1            0.7427
# 3         1                 1            0.9228
# 4         0                 0            0.8901

# %%
predictions = predict_model(best, data=df, raw_score=True)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_35890" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35890_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_35890_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_35890_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_35890_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_35890_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_35890_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_35890_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_35890_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35890_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35890_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_35890_row0_col1" class="data row0 col1" >0.8920</td>
#       <td id="T_35890_row0_col2" class="data row0 col2" >0.9518</td>
#       <td id="T_35890_row0_col3" class="data row0 col3" >0.7979</td>
#       <td id="T_35890_row0_col4" class="data row0 col4" >0.9146</td>
#       <td id="T_35890_row0_col5" class="data row0 col5" >0.8523</td>
#       <td id="T_35890_row0_col6" class="data row0 col6" >0.7677</td>
#       <td id="T_35890_row0_col7" class="data row0 col7" >0.7722</td>
#     </tr>
#   </tbody>
# </table>
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket       Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.250000   NaN        S
# 1  female  38.0      1      0          PC 17599  71.283302   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.925000   NaN        S
# 3  female  35.0      1      0            113803  53.099998  C123        S
# 4    male  35.0      0      0            373450   8.050000   NaN        S
#
#    Survived  prediction_label  prediction_score_0  prediction_score_1
# 0         0                 0              0.9285              0.0715
# 1         1                 1              0.1587              0.8413
# 2         1                 1              0.2573              0.7427
# 3         1                 1              0.0772              0.9228
# 4         0                 0              0.8901              0.1099

# %%
save_model(best, 'my_best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['PassengerId', 'Pclass', 'Age',
#                                               'SibSp', 'Parch', 'Fare'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean',
#                                                                verbose='deprecated'))),
#                  ('categorical_imputer',
#                   Transforme...
#                                                                handle_unknown='value',
#                                                                hierarchy=None,
#                                                                min_samples_leaf=20,
#                                                                return_df=True,
#                                                                smoothing=10,
#                                                                verbose=0))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=123,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'my_best_pipeline.pkl')

# %%
loaded_model = load_model('my_best_pipeline')
print(loaded_model)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['PassengerId', 'Pclass', 'Age',
#                                              'SibSp', 'Parch', 'Fare'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean',
#                                                               verbose='deprecated'))),
#                 ('categorical_imputer'...
#                                                               handle_unknown='value',
#                                                               hierarchy=None,
#                                                               min_samples_leaf=20,
#                                                               return_df=True,
#                                                               smoothing=10,
#                                                               verbose=0))),
#                 ('trained_model',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=1000,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=123,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %% [markdown]
# ### Submit

# %%
test_predictions = predict_model(best, data=test_df)
test_predictions
# Out:
#      PassengerId  Pclass                                         Name     Sex  \
# 0            723       2                 Gillespie, Mr. William Henry    male
# 1            724       2                      Hodges, Mr. Henry Price    male
# 2            725       1                Chambers, Mr. Norman Campbell    male
# 3            726       3                          Oreskovic, Mr. Luka    male
# 4            727       2  Renouf, Mrs. Peter Henry (Lillian Jefferys)  female
# ..           ...     ...                                          ...     ...
# 164          887       2                        Montvila, Rev. Juozas    male
# 165          888       1                 Graham, Miss. Margaret Edith  female
# 166          889       3     Johnston, Miss. Catherine Helen "Carrie"  female
# 167          890       1                        Behr, Mr. Karl Howell    male
# 168          891       3                          Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch      Ticket       Fare Cabin Embarked  \
# 0    34.0      0      0       12233  13.000000   NaN        S
# 1    50.0      0      0      250643  13.000000   NaN        S
# 2    27.0      1      0      113806  53.099998    E8        S
# 3    20.0      0      0      315094   8.662500   NaN        S
# 4    30.0      3      0       31027  21.000000   NaN        S
# ..    ...    ...    ...         ...        ...   ...      ...
# 164  27.0      0      0      211536  13.000000   NaN        S
# 165  19.0      0      0      112053  30.000000   B42        S
# 166   NaN      1      2  W./C. 6607  23.450001   NaN        S
# 167  26.0      0      0      111369  30.000000  C148        C
# 168  32.0      0      0      370376   7.750000   NaN        Q
#
#      prediction_label  prediction_score
# 0                   0            0.7317
# 1                   0            0.7945
# 2                   0            0.5337
# 3                   0            0.8182
# 4                   1            0.5876
# ..                ...               ...
# 164                 0            0.6881
# 165                 1            0.9053
# 166                 0            0.5140
# 167                 1            0.6124
# 168                 0            0.7849
#
# [169 rows x 13 columns]

# %%
sub_df = pd.read_csv('pre_practice_task_2023/2023 Pre Practice (Task)/Titanic_sample/answer.csv')
sub_df
# Out:
#      PassengerId  Survived
# 0            723         0
# 1            724         0
# 2            725         1
# 3            726         0
# 4            727         1
# ..           ...       ...
# 164          887         0
# 165          888         1
# 166          889         0
# 167          890         1
# 168          891         0
#
# [169 rows x 2 columns]

# %%
sub_df = sub_df.merge(test_predictions, on='PassengerId')[['PassengerId', 'prediction_label']].rename(columns={'prediction_label': 'Survived'})

# %%
sub_df.to_csv('231129_Strawberry Salad 2.csv', index=False)

# %% [markdown]
# # 2022

# %%
import sys
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# ##Columms

# %%
" ".join(list(df.columns))

# %% [markdown]
# ##Missing Value Search

# %%
df.isnull().sum()

# %% [markdown]
# ##General Data Statistics Value

# %%
df.describe()
#df.info()

# %% [markdown]
# #Data Visualisation

# %% [markdown]
# ##Quantity Data

# %%
def heat_map_plt(dataset):
  plt.figure(figsize=(12, 9))
  sns.heatmap(dataset.corr(), annot=True, cmap="YlGnBu", linewidth=.7)

# %%
heat_map_plt(df)

# %%
def outlier(df):
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    IQR = Q3 - Q1
    return [(Q1 - 1.5 * IQR), (Q3 + 1.5 * IQR)]

    #df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
def plot_with_features(dfm, column, show_outlier=False):
    f, ax = plt.subplots(nrows= int(len(column) / 2) + len(column) % 2, ncols=2, figsize=(15, 15))
    for i in range(len(column)):
        ax[int(i / 2), i % 2].scatter([i for i in range(len(dfm))], dfm[column[i]], edgecolor="white", linewidth=.5)
        ax[int(i / 2), i % 2].set_xlabel("id")
        ax[int(i / 2), i % 2].set_ylabel(column[i])
        if show_outlier:
            lower, upper = outlier(dfm[column[i]])
            ax[int(i / 2), i % 2].plot([i for i in range(len(dfm))], [lower for i in range(len(dfm))], color = "red")
            ax[int(i / 2), i % 2].plot([i for i in range(len(dfm))], [upper for i in range(len(dfm))], color = "red")
    f.tight_layout()
    plt.show()

# %%
plot_with_features(df, ["age", "balance", "duration", "campaign", "pdays", "previous"], True)

# %% [markdown]
# ##Quality Data

# %%
def piechart_with_features(dfm, column):
    f, ax = plt.subplots(nrows= int(len(column) / 2) + len(column) % 2, ncols=2, figsize=(15, 15))
    for i in range(len(column)):
        count_map = {}
        for e in dfm[column[i]]:
            if e not in count_map:
                count_map[e] = 0
            else:
                count_map[e] += 1
        ax[int(i / 2), i % 2].pie(count_map.values(), labels=count_map.keys(), autopct="%.2f%%")
        ax[int(i / 2), i % 2].set_xlabel(column[i])
    f.tight_layout()
    plt.show()

# %%
piechart_with_features(df, ["job", "marital", "education", "housing", "loan", "contact", "poutcome", "y"])

# %% [markdown]
# #Drop features and encoding features

# %%
df.columns

# %% [markdown]
# #Select comparative value

# %% [markdown]
# we use column y as y_train value

# %%
ydf = df.groupby('y', group_keys=False).apply(lambda x: x.sample(len(df[df['y'] == "yes"])))

# %%
plot_with_features(ydf, ["age", "balance", "duration", "campaign", "pdays", "previous"], True)

# %%
piechart_with_features(ydf, ["job", "marital", "education", "housing", "loan", "contact", "poutcome", "y"])

# %% [markdown]
# # Preprocess data
# ### Dropped Features
# 1. id - not so meaningful info
# 2. duration - should be discarded because we get this info after the result happenend.
# 3. job - too many of them
# 4. month - provide useful info?
#
# ### Encoded features
# 1. pdays - aware of meaning of numeric
#
#   one-hot:
#   *   contact
#
#
#
# ### TODO: Maybe drop outliner (stat101)
# ### To Improve: Maybe there're many unknown value?

# %% [markdown]
# ###Method 0:

# %% [markdown]
# Outlier

# %%
def remove_outlier(dfm, column):
    df_copy = dfm.copy()
    outlier_value = []
    for e in column:
        outlier_value.append(outlier(df[e]))
    for i in range(len(column)):
        df_copy = df_copy[~((df_copy[column[i]] < outlier_value[i][0]) | (df_copy[column[i]] > outlier_value[i][1]))]
    return df_copy

# %%
rdf = remove_outlier(ydf, ["balance", "duration", "campaign"])

# %%
plot_with_features(rdf, ["age", "balance", "duration", "campaign", "pdays", "previous"])

# %%
len(rdf)

# %% [markdown]
# Encoding

# %%
tf = rdf
#month_encoded
month_list = ["jan", "feb", "mar", "apr", "may", "jun", "jul", "aug", "sep", "oct", "nov", "dec"]
mapped_month = {month_list[i]: i + 1 for i in range(len(month_list))}
tf["month"] = tf["month"].apply(mapped_month.get)

#dafault encoded
tf["default"] = tf["default"].apply(lambda x: 0 if x == "no" else 1)
#housing encoded
tf["housing"] = tf["housing"].apply(lambda x: 0 if x == "no" else 1)
#loan encoded
tf["loan"] = tf["loan"].apply(lambda x: 0 if x == "no" else 1)
#job encoded
tf["job"] = tf["job"].astype("category").cat.codes
#y encoded
tf["y"] = tf["y"].apply(lambda x: 0 if x == "no" else 1)
#education encoded -> one hot
#contact encoded -> one hot
#marital encoded -> one hot
#poutome encoded -> one hot
tf_oh = pd.get_dummies(tf, columns=["education", "contact", "marital", "poutcome"])
#tf_oh.drop(["education", "contact", "marital", "poutcome"], axis=1)

# %%
from sklearn.feature_selection import VarianceThreshold
threshold_n=0.25
#threshold_n* (1 - threshold_n)
sel = VarianceThreshold(threshold=threshold_n)
sel_var=sel.fit_transform(tf_oh)
tf_new = tf_oh[tf_oh.columns[sel.get_support(indices=True)]]

# %% [markdown]
# Dropped Features

# %%
#according to dropped features analysis
tf_drop = tf_new.drop(["id", "duration", "job"], axis=1)
heat_map_plt(tf_drop)

# %%
print(len(tf_drop.columns), len(tf_drop))

# %%
# Zoon Data
zf = tf_drop
zf['y'] = tf_oh['y']
zf

# %% [markdown]
# ###Method 1:
# * use only valid info features
# * feature that has 'unknown': cat features
# * pdays?
#
# |cat|unknown|
# ---|---
# |marital |0 |
# |edu|165 |
# |default|0|
# |housing|0|
# |loan|0|
# |contact|1172|
# |month|0|
# |poutcome|3281|

# %%
# id age job marital education default balance housing loan contact month duration campaign pdays previous poutcome y

# %%
rdf = remove_outlier(df, ["balance", "duration", "campaign", "previous"])
len(rdf)

# %%
cat_names =  ['marital', 'education', 'default', 'housing', 'loan']
cont_names = ['age', 'balance', 'campaign', 'pdays', 'previous']

# %%
# has many unknown
df['poutcome'].value_counts()

# %%
dfc = []
for c in cat_names:
  dfc.append(df[c].value_counts())

# %%
dfc

# %%
tf['education'].unique()

# %%
RANDOM_STATE = 42

# encode func education
def encode_education(x):
  if x == 'primary':
    return 1
  elif x == 'secondary':
    return 2
  elif x == 'tertiary':
    return 3
  else:
    return 0

def preprocess_g(df):
  # features use
  cat_names =  ['marital', 'education', 'default', 'housing', 'loan']
  cont_names = ['age', 'balance', 'campaign', 'pdays', 'previous']

  # cdf: df w/ only use features (include outliner)
  cdf = df[cat_names + cont_names + ['y']]

  # drop the row that has education == unknown
  # cdf = cdf[cdf['education'] != 'unknown']

  # encode
  tf = cdf.copy()

  tf["default"] = tf["default"].apply(lambda x: 0 if x == "no" else 1)
  tf["housing"] = tf["housing"].apply(lambda x: 0 if x == "no" else 1)
  tf["loan"] = tf["loan"].apply(lambda x: 0 if x == "no" else 1)
  tf['pdays'] = tf['pdays'].apply(lambda x: 999 if x == -1 else x) # or just drop pdays
  tf["education"] = tf["education"].apply(encode_education) # unknown -> 0

  tf = pd.get_dummies(tf, columns=["marital"])

  tf["y"] = tf["y"].apply(lambda x: 0 if x == "no" else 1)

  return tf

# %%
tf = preprocess_g(df)

rdf = remove_outlier(tf, ["balance"]) # rdf: tf remove outliner; balance

# %% [markdown]
# ## Imbalance Fix
# By Downsample y = 0

# %%
# tdf: dataset use
tdf = tf
# tdf = rdf # remove outliner
tdf_0 = tf[tf['y'] == 0]
tdf_1 = tf[tf['y'] == 1]
print(tdf_0.shape, tdf_1.shape)

t_vc = tdf['y'].value_counts()
print(t_vc)
print(t_vc[1]/(t_vc[0]+t_vc[1])) # moderate

# %%
from sklearn.utils import resample

tdf_0_downsample = resample(tdf_0,
             replace=True,
             n_samples=len(tdf_1),
             random_state=RANDOM_STATE)

print(tdf_0_downsample.shape, tdf_1.shape)

# %%
tdf_downsample = tdf_0_downsample.append(tdf_1)
tdf_downsample.shape

# %%
remove_outlier(tdf_downsample, ["balance"]).shape # rdf: tf remove outliner; balance

# %% [markdown]
# ##Minority Expansion

# %%
def minority_expansion(dfm, column, major_val, minor_val, RAND_STATE=42):
    import warnings
    warnings.filterwarnings('ignore')
    minor = dfm[dfm[column] == minor_val]
    major = dfm[dfm[column] == major_val]
    folds = int(len(major) / len(minor))
    residue = len(major) - len(minor) * folds
    for i in range(folds):
        major = major.append(minor, ignore_index=True)
    major = major.append(minor.sample(n = residue, random_state=RAND_STATE), ignore_index=True)
    return major.sample(frac=1, random_state=RAND_STATE)

# %%
mi_ex = minority_expansion(tf, "y", 0, 1)

# %% [markdown]
# ##Random Reshuffle

# %%
def random_reshuffle(dfm, column, major_val, minor_val, RAND_STATE=42):
    import warnings
    import random
    warnings.filterwarnings('ignore')
    minor = dfm[dfm[column] == minor_val]
    major = dfm[dfm[column] == major_val]
    random.seed(RANDOM_STATE)
    random_select = random.randint(0, len(major))
    new_frame = pd.DataFrame()
    for i in range(random_select):
        new_frame = new_frame.append(minor.sample(n=1), ignore_index=True)
    for i in range(len(dfm) - random_select):
        new_frame = new_frame.append(major.sample(n=1), ignore_index=True)
    return new_frame.sample(frac=1, random_state=RANDOM_STATE)

# %%
rd_re = random_reshuffle(tf, "y", 0, 1)

# %% [markdown]
# # Split data: stratified & k-fold

# %%
# split data: stratified & k-fold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# x, y
x = tdf_downsample.drop(columns='y', axis=1)
y = tdf_downsample['y']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=42)
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train) # apply scaling on training data
x_test_scaled = scaler.transform(x_test)

# %%
scaler

# %%
len(x_train), len(x_test)

# %%
y_train.value_counts() # so imbalance na

# %%
# y_vc = y_train.value_counts()
y_vc = y.value_counts()
y_vc[1]/(y_vc[0]+y_vc[1]) # balanced

# %% [markdown]
# # Model Selection (sklearn)
# score so bad jung

# %%
def test_regression(dfm, column, config=False):
    from sklearn.model_selection import cross_val_score
    from sklearn.linear_model import LogisticRegressionCV
    from sklearn.ensemble import RandomForestClassifier
    from xgboost import XGBClassifier

    RANDOM_STATE = 42

    x = dfm.drop(columns=column, axis=1)
    y = dfm[column]

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=42)
    scaler = StandardScaler()
    x_train_scaled = scaler.fit_transform(x_train) # apply scaling on training data
    x_test_scaled = scaler.transform(x_test)

    c = 0

    print("logistic classifier")
    clf = LogisticRegressionCV(cv=5, random_state=RANDOM_STATE, scoring='f1')
    score = cross_val_score(clf, x_train_scaled, y_train, cv=5, scoring='f1')
    print(score)
    a = score
    c += score.sum()

    print("random forest classifier")
    ranf = RandomForestClassifier(random_state=RANDOM_STATE)
    score = cross_val_score(ranf, x_train, y_train, scoring="f1", cv=5)
    print(score)
    b = score
    c += score.sum()

    print("xgb classifier")
    xgb = XGBClassifier(random_state=RANDOM_STATE)
    score = cross_val_score(xgb, x_train, y_train, scoring="f1", cv=5)
    print(score)
    d = score
    c += score.sum()

    if config:
      return c, [a, b, d]

    return scaler

# %%
test_regression(zf, 'y')

# %%
zf.shape

# %%
test_regression(tdf_downsample, 'y')

# %%
test_regression(mi_ex, "y")

# %%
test_regression(rd_re, "y")

# %%
state = []
for i in range(1234):
  dst = random_reshuffle(tf, "y", 0, 1, i)
  c, li = test_regression(dst, "y", True)
  state.append([-c, li, i])

print(sorted(state))

# %%
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
clf = LogisticRegressionCV(cv=5, random_state=RANDOM_STATE, scoring='f1')
cross_val_score(clf, x_train_scaled, y_train, cv=5, scoring='f1')

# %%
ranf = RandomForestClassifier(random_state=RANDOM_STATE)
cross_val_score(ranf, x_train, y_train, scoring="f1", cv=5)

# %%
xgb = XGBClassifier(random_state=RANDOM_STATE)
cross_val_score(xgb, x_train, y_train, scoring="f1", cv=5)

# %% [markdown]
# # Model Fine-tune

# %% [markdown]
# ## fastai model (deep learning)
# Approch 1: not so good, high valid_loss, acc= 0.79

# %%
from fastai.tabular.all import *

# %%
# Approch 1
# cat_names =  ['marital', 'education', 'default', 'housing',
#               'loan', 'contact', 'month', 'poutcome']

# cont_names = ['age', 'balance', 'campaign', 'pdays', 'previous']

# Approch 2
cat_names =  ['marital', 'education', 'default', 'housing', 'loan']

cont_names = ['age', 'balance', 'campaign', 'pdays', 'previous']

y_names = 'y'

splits = RandomSplitter(valid_pct=0.2)(range_of(df))

to = TabularPandas(df, procs=[Categorify, FillMissing, Normalize],
                   cat_names = cat_names,
                   cont_names = cont_names,
                   y_names=y_names,
                   splits=splits)

to.xs.iloc[:2]

# %%
dls = to.dataloaders(bs=64)

dls.show_batch()

# %% [markdown]
# Approch 2

# %%
learn2 = tabular_learner(dls, metrics=accuracy)

# %%
learn2.fit_one_cycle(1)

# %%
learn2.show_results()

# %% [markdown]
# Approch 1

# %%
learn = tabular_learner(dls, metrics=accuracy)

# %%
learn.fit_one_cycle(1)

# %%
learn.show_results()

# %% [markdown]
# Approach 3

# %%
import sklearn.metrics as skm
def binaccu():
    return skm_to_fastai(skm.accuracy_score)

# %%
cont_names = ['age', 'balance', 'campaign', 'pdays', 'previous']
y_names = 'y'

splits = RandomSplitter(valid_pct=0.1)(range_of(tf_drop))
fo = TabularPandas(tf_drop, procs=[Categorify, FillMissing, Normalize],
                  cont_names = cont_names,
                  y_names=y_names,
                  splits=splits)
dls = fo.dataloaders(bs=64)
learn = tabular_learner(dls, n_out=1, metrics=[binaccu()])
learn.fit_one_cycle(10, 1e-3)
learn.show_results()

# %%
learn.lr_find()

# %%
from sklearn.metrics import confusion_matrix
preds, targs = learn.get_preds()
m = nn.Sigmoid()
confusion_matrix(torch.round(m(preds.view(-1))).numpy(), targs.view(-1).numpy())

# %%
tf_drop["y"].value_counts()
#VERY BAD NOW

# %% [markdown]
# ## XGBoost

# %%
def getXYScaler(df, target):
  x = df.drop(columns=target, axis=1)
  y = df[target]
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=42)
  scaler = StandardScaler()
  x_train_scaled = scaler.fit_transform(x_train) # apply scaling on training data
  x_test_scaled = scaler.transform(x_test)
  return x_train, x_test, y_train, y_test, x_train_scaled, x_test_scaled, scaler

# %%
def gridsearch_model(df, target, model, param_grid, scaled=False):
  x = df.drop(columns=target, axis=1)
  y = df[target]
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=42)
  scaler = StandardScaler()
  x_train_scaled = scaler.fit_transform(x_train) # apply scaling on training data
  x_test_scaled = scaler.transform(x_test)
  clf = GridSearchCV(model, param_grid, scoring='f1', cv=10)
  if(scaled): clf.fit(x_train_scaled, y_train)
  else: clf.fit(x_train, y_train)
  return clf.best_estimator_

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
def plot_cm(df, model, scaled=False):
  x_train, x_test, y_train, y_test, x_train_scaled, x_test_scaled, scaler = getXYScaler(df, 'y')
  if(scaled): y_pred = model.predict(x_test_scaled)
  else: y_pred = model.predict(x_test)
  cm = confusion_matrix(y_test, y_pred, labels=model.classes_)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                display_labels=model.classes_)
  disp.plot()
  plt.show()

# %% [markdown]
# ### Grid Search for each dataset

# %%
param_grid = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
}
xgb = XGBClassifier(random_state=RANDOM_STATE)
xgb_tdf = gridsearch_model(tdf_downsample, 'y', xgb, param_grid)
xgb_mi = gridsearch_model(mi_ex, 'y', xgb, param_grid)
xgb_re = gridsearch_model(rd_re, 'y', xgb, param_grid)

# %%
plot_cm(mi_ex, xgb_mi)

# %% [markdown]
# ## Random Forest

# %%
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

rf = RandomForestClassifier(random_state=RANDOM_STATE)

rf_tdf = gridsearch_model(tdf_downsample, 'y', rf, param_grid)
rf_mi = gridsearch_model(mi_ex, 'y', rf, param_grid)
rf_re = gridsearch_model(rd_re, 'y', rf, param_grid)

# %%
rf_re

# %% [markdown]
# ## Logistic Regression

# %%
lg = LogisticRegression(random_state=RANDOM_STATE)

param_grid = {"C":np.logspace(-3,3,7), "penalty":["l1","l2"]} # l1 lasso l2 ridge

lg_tdf = gridsearch_model(tdf_downsample, 'y', lg, param_grid, scaled=True)
lg_mi = gridsearch_model(mi_ex, 'y', lg, param_grid, scaled=True)
lg_re = gridsearch_model(rd_re, 'y', lg, param_grid, scaled=True)

# %%
plot_cm(mi_ex, lg_mi, scaled=True)

# %% [markdown]
# # Save Model

# %%
import pickle
def save_model(fn, model):
  # save the model to disk
  filename = fn
  # filename = 'finalized_model.sav'
  pickle.dump(model, open(filename, 'wb'))

# %%
models = ['xgb_tdf', 'xgb_mi', 'xgb_re', 'rf_tdf', 'rf_mi', 'rf_re', 'lg_tdf', 'lg_mi', 'lg_re']

# %%
rf_re

# %%
for m in models:
  save_model(m + '.sav', locals()[m])
  print(locals()[m])

# %%
filename = models[8] + '.sav'
print(filename)
loaded_model = pickle.load(open(filename, 'rb'))
loaded_model

# %%
print(loaded_model)

# %% [markdown]
# # Model Evaluation

# %%
test_df = pd.read_csv('test.csv?raw=True')

# %%
def get_df_name(df):
  if df.equals(tdf):
    return 'tdf'
  elif df.equals(tdf_downsample):
    return 'tdf_downsample'
  elif df.equals(mi_ex):
    return 'mi_ex'
  elif df.equals(rd_re):
    return 'rd_re'
  else:
    return 'unknown'

# %%
from sklearn import metrics
import matplotlib.pyplot as plt

def model1(test_df, df, model_fn, preprocess=preprocess_g, scaled=False):
  _, _, _, _, _, _, scaler = getXYScaler(df, 'y') # get scaler

  df_name = get_df_name(df)
  print(f'test model: {model_fn}, data use: {df_name}')
  model1 = pickle.load(open(model_fn, 'rb'))

  x_test = test_df.copy()
  x_test = preprocess(x_test)
  y_test = x_test['y']
  x_test = x_test.drop('y', axis=1)
  if(scaled): x_test = scaler.transform(x_test)
  y_logit = model1.predict_proba(x_test)[::,1]
  fpr, tpr, _ = metrics.roc_curve(y_test, y_logit)
  auc = metrics.roc_auc_score(y_test, y_logit)
  plt.figure(figsize=(30, 6))
  plt.subplot(151)
  plt.plot(fpr,tpr,label="AUC="+str(auc))
  plt.ylabel('True Positive Rate')
  plt.xlabel('False Positive Rate')
  plt.legend(loc=4)
  plt.title(model_fn + ' | ' + df_name)
  plt.savefig(model_fn + ' | ' + df_name + '.png')
  # files.download(model_fn + ' | ' + df_name + '.png')

def submit(test_df, df, model, preprocess=None, scaled=False):
  _, _, _, _, _, _, scaler = getXYScaler(df, 'y') # get scaler

  x_test = test_df.copy()
  if(preprocess != None): x_test = preprocess(x_test)
  x_test = x_test.drop('y', axis=1)
  if(scaled): x_test = scaler.transform(x_test)
  y_pred = model.predict_proba(x_test) # use y_pred[:, 1]
  # print(np.array(y_pred)[:, 1])
  # y_pred = model.predict(x_test)
  sub = pd.DataFrame(np.array(y_pred)[:, 1], columns=['y'])
  sub['id'] = test_df['id']
  sub = sub[['id', 'y']]
  return sub

# %%
files.download(model_fn + ' | ' +  + '.png')

# %%
model1(test_df, tdf, models[0] + '.sav')

# %%
for m in models:
  if(m[-2:] == 'df'):
    model1(test_df, tdf_downsample, m + '.sav')
  elif(m[-2:] == 'mi'):
    model1(test_df, mi_ex, m + '.sav')
  elif(m[-2:] == 're'):
    model1(test_df, rd_re, m + '.sav')

# %% [markdown]
# # Submit

# %%
sample = pd.read_csv('submission_sample.csv?raw=True')
# sample.head()
sample

# %%
test_df = pd.read_csv('test.csv?raw=True')

# %%
test_df.head()

# %%
def submit(test_df, df, model, preprocess=None, scaled=False):
  _, _, _, _, _, _, scaler = getXYScaler(df, 'y') # get scaler

  x_test = test_df.copy()
  if(preprocess != None): x_test = preprocess(x_test)
  x_test = x_test.drop('y', axis=1)
  if(scaled): x_test = scaler.transform(x_test)
  y_pred = model.predict_proba(x_test) # use y_pred[:, 1]
  # print(np.array(y_pred)[:, 1])
  # y_pred = model.predict(x_test)
  sub = pd.DataFrame(np.array(y_pred)[:, 1], columns=['y'])
  sub['id'] = test_df['id']
  sub = sub[['id', 'y']]
  return sub

# %%
submit(test_df, tdf_downsample, xgb_tdf, preprocess=preprocess_g).to_csv('submission_xgb_tdf.csv', index=False)

# %%
from google.colab import files
files.download('submission_xgb_tdf.csv')

# %%
submit(test_df, mi_ex, lg_mi, preprocess=preprocess_g, scaled=True).to_csv('sub2.csv', index=False)

# %%
pd.read_csv('submission.csv')

# %%
pd.read_csv('sub2.csv')
